# %%
pip install kaggle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105786 sha256=6d06534677c9d307c663b9716bf972ee37767b4cec103f2ffa9faa6421bf8a57
#   Stored in directory: /Users/caterina/Library/Caches/pip/wheels/46/d2/26/84d0a1acdb9c6baccf7d28cf06962ec80529fe1ad938489983
# Successfully built kaggle
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import os

# %%
data = "attacks.csv"

# %%
import os
print(os.getcwd()) # pasa saber donde se encuentra el archivo csv
# Out:
# /Users/caterina/IronHack/Projects

# %%
path = "/Users/caterina/IronHack/Projects"

# %%
try:
    df = pd.read_csv("attacks.csv")
    print("Archivo leído exitosamente")
except FileNotFoundError:
    print("Error: El archivo no se encuentra en el directorio actual")
except Exception as e:
    print(f"Ocurrió un error al leer el archivo: {e}")
# Out:
# Ocurrió un error al leer el archivo: 'utf-8' codec can't decode byte 0xa0 in position 698: invalid start byte

# %%
df = pd.read_csv(data, encoding="latin-1")
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df = pd.read_csv(data, encoding="ISO-8859-1")
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# observaciones:
# - la columna Case Number es la fecha, que también aparece como columna (Date)

# %%
df["Type"].value_counts()
# Out:
# Type
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df.Age.value_counts()
# Out:
# Age
# 17                154
# 18                150
# 19                142
# 20                141
# 15                139
#                  ...
# 20?                 1
#  28                 1
# 7      &    31      1
#  30                 1
# 13 or 14            1
# Name: count, Length: 157, dtype: int64

# %%
df.pdf.value_counts()
# Out:
# pdf
# 1923.00.00.a-NJ fisherman.pdf      2
# 1935.06.05.R-SolomonIslands.pdf    2
# 1916.12.08.a-b-German.pdf          2
# 1907.10.16.R-HongKong.pdf          2
# 1921.11.27.a-b-Jack.pdf            2
#                                   ..
# 1999.10.30.a-TroyJesse.pdf         1
# 1999.10.30.b-Dolsky.pdf            1
# 1999.11.00.a-Morson.pdf            1
# 1999.11.00.b-Bayo.pdf              1
# ND-0001-Ceylon.pdf                 1
# Name: count, Length: 6291, dtype: int64

# %%
df.Activity.value_counts()
# Out:
# Activity
# Surfing                                   971
# Swimming                                  869
# Fishing                                   431
# Spearfishing                              333
# Bathing                                   162
#                                          ...
# Playing with a frisbee in the shallows      1
# Sinking of the ferryboat Dumaguete          1
# Wreck of the Storm King                     1
# Feeding mullet to sharks                    1
# Wreck of  large double sailing canoe        1
# Name: count, Length: 1532, dtype: int64

# %%
df.Injury.value_counts()
# Out:
# Injury
# FATAL                                                                                     802
# Survived                                                                                   97
# Foot bitten                                                                                87
# No injury                                                                                  82
# Leg bitten                                                                                 72
#                                                                                          ...
# Cut foot, but injury caused by fishing line, not the shark                                  1
# Left foot bitten after he accidentally stepped on the shark         PROVOKED INCIDENT       1
# 2 puncture wounds in left leg                                                               1
# PROVOKED INCIDENT    Knee bitten by shark trapped in net                                    1
# ...

# %%
df["Fatal (Y/N)"].value_counts()
# Out:
# Fatal (Y/N)
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# M             1
# 2017          1
# N             1
# y             1
# Name: count, dtype: int64

# %%
df["Unnamed: 22"].value_counts()
# Out:
# Unnamed: 22
# stopped here    1
# Name: count, dtype: int64

# %%
# columnas que no aportan información:
# - Case Number o Date
# - Name
# - pdf
# - Unnamed: 22
# - Unnamed: 23
# - Case Number.1 es la fecha otra vez
# - Case Number.2 es otra vez la fecha
